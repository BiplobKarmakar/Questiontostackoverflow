# %% [markdown]
# <a href="https://colab.research.google.com/github/BiplobKarmakar/Questiontostackoverflow/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-089f9833-05c4-43de-928b-9fd72777dc15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-089f9833-05c4-43de-928b-9fd72777dc15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
df = pd.read_csv("test.csv")
display(df.head())
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOi328DZcweGB4_nOyHA3Dy6o1YKYKyf3COx...      M   Y   Y    1   B
# 1  b'gAAAAABinOikutEIBjkUXl9lYTg4RI6jc4NfiMUCcVsn...      M   Y   Y    1   B
# 2  b'gAAAAABinOjBM70jBXOroAlUSq5lNXMd_oP0PU7jLQE5...      M   Y   N    1   B
# 3  b'gAAAAABinOimitAnqlgOcqnD_LeNL3WEbXNGvjd3QVPi...      M   Y   Y    1   D
# 4  b'gAAAAABinOi3W9p3Oka5MV_dc2TeorZUcIWOnnODSx7E...      M   Y   Y    1   D
#
#   s17 s18  s48 s52  ...        n6        n7        n8         n9        n10  \
# 0   D   D    0   l  ...  0.026301 -9.200175  2.122970   6.646617   4.801224
# 1   C   B    1   l  ...  0.010774 -8.897092  1.770889  11.046294   6.407230
# 2   D   B    1   l  ...  0.016837 -9.173660  1.871872   2.805834   5.481219
# 3   D   B    0   1  ...  0.015684 -9.178200  1.675028   6.354938   5.427266
# 4   C   B    1   1  ...  0.006406 -8.726633  1.963535   6.810158  11.487845
#
#         n11  n12 n13       n14 n15
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'gender',
#  's11',
#  's12',
#  's13',
#  's16',
#  's17',
#  's18',
#  's48',
#  's52',
#  's53',
#  's54',
#  's55',
#  's56',
#  's57',
#  's58',
#  's59',
#  's69',
#  's70',
#  's71',
#  'n1',
#  'n2',
#  'n3',
#  'n4',
#  'n5',
#  'n6',
#  'n7',
#  'n8',
#  'n9',
#  'n10',
#  'n11',
#  'n12',
#  'n13',
#  'n14',
#  'n15']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-35e37c40-51fa-44e3-9f24-ea7174ce6327" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35e37c40-51fa-44e3-9f24-ea7174ce6327">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv
#      <input type="file" id="files-2153f3d2-ddb7-4d14-bb53-6c4e077a814e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2153f3d2-ddb7-4d14-bb53-6c4e077a814e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df_train = pd.read_csv("train.csv")
display(df_train.head())
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1   D
# 1  b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1   D
# 2  b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1   D
# 3  b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1   D
# 4  b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1   B
#
#   s17 s18  s48 s52  ...        n7        n8        n9       n10       n11 n12  \
# 0   D   B    0   1  ... -9.126056  1.732291  3.698504  4.804517  1.544484   0
# 1   D   B    1   1  ... -9.098287  1.505885  6.791357  6.110416  1.712354   0
# 2   D   B    0   1  ... -9.234894  1.503828  4.109685  3.953226  1.804260   0
# 3   D   B    0   1  ... -9.378025  1.485863  7.265876  4.559419  1.537645   0
# 4   D   D    1   l  ... -9.261962  1.619210  3.737647  4.052003  1.637831   0
#
#    n13       n14 n15 label
# ...

# %%
list(df_train.columns)
# Out:
# ['id',
#  'gender',
#  's11',
#  's12',
#  's13',
#  's16',
#  's17',
#  's18',
#  's48',
#  's52',
#  's53',
#  's54',
#  's55',
#  's56',
#  's57',
#  's58',
#  's59',
#  's69',
#  's70',
#  's71',
#  'n1',
#  'n2',
#  'n3',
#  'n4',
#  'n5',
#  'n6',
#  'n7',
#  'n8',
#  'n9',
#  'n10',
#  'n11',
#  'n12',
#  'n13',
#  'n14',
#  'n15',
#  'label']

# %%
df = pd.read_csv("test.csv")
display(df.head())

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1fcd7be7-115e-4eca-8dc2-ba78dca0d013" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fcd7be7-115e-4eca-8dc2-ba78dca0d013">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_submission.csv to sample_submission.csv

# %%
df_submission = pd.read_csv("sample_submission.csv")
display(df.head())
# Out:
#                                                   id  label
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      0
# 1  b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      0
# 2  b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      0
# 3  b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      0
# 4  b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      1
